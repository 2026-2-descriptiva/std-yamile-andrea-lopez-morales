# %%
import pandas as pd

# %%
#          Identificadores directos: name, document_id, email, loyalty_card_number
#             Cuasi-identificadores: age, city, occupation
# Información sensible/confidencial: annual_spend
raw = pd.read_csv("../data/raw.csv")
raw.head()
# Out:
#                 name  document_id                             email  \
# 0    Camila González   1000000001    camila.gonzalez1@gmail.example
# 1       Mateo Ospina   1000000002       mateo.ospina2@yahoo.example
# 2        Diana Duque   1000000003      diana.duque3@outlook.example
# 3  Sebastián Álvarez   1000000004  sebastian.alvarez4@yahoo.example
# 4      Mariana Henao   1000000005    mariana.henao5@outlook.example
#
#    loyalty_card_number  age      city             occupation  annual_spend
# 0         840000000001   25  Envigado            Comerciante       2580000
# 1         840000000002   36      Cali  Ingeniero de sistemas       5400000
# 2         840000000003   38    Bogotá                Docente       5320000
# 3         840000000004   67    Itagüí                Abogada       4290000
# 4         840000000005   29    Bogotá            Comerciante       3670000

# %%
# Información pública externa
auxiliary = pd.read_csv("../data/auxiliary.csv")
auxiliary.head()
# Out:
#               name  age       city             occupation
# 0      Laura Gómez   47   Rionegro             Arquitecta
# 1  Andrés Restrepo   38   Envigado  Ingeniero de sistemas
# 2     Camila Henao   29    Pereira     Diseñadora gráfica
# 3     Carlos Muñoz   61      Bello   Técnico electricista
# 4   Natalia Ospina   34  Manizales                Docente

# %%
# La combinación de los cuasi-identificadores puede permitir la reidentificación de individuos
quasi_identifiers = ["age", "city", "occupation"]

reidentified = auxiliary.merge(
    anonymized,
    on=quasi_identifiers,
    how="inner",
)

reidentified.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 # La combinación de los cuasi-identificadores puede permitir la reidentificación de individuos
#       2 quasi_identifiers = ["age", "city", "occupation"]
#       3
#       4 reidentified = auxiliary.merge(
# ----> 5     anonymized,
#       6     on=quasi_identifiers,
#       7     how="inner",
#       8 )
#
# NameError: name 'anonymized' is not defined

# %%
# Paso 1: eliminación de los identificadores directos

anonymized = raw.drop(columns=["name", "email"])
anonymized.head()
# Out:
#    document_id  loyalty_card_number  age      city             occupation  \
# 0   1000000001         840000000001   25  Envigado            Comerciante
# 1   1000000002         840000000002   36      Cali  Ingeniero de sistemas
# 2   1000000003         840000000003   38    Bogotá                Docente
# 3   1000000004         840000000004   67    Itagüí                Abogada
# 4   1000000005         840000000005   29    Bogotá            Comerciante
#
#    annual_spend
# 0       2580000
# 1       5400000
# 2       5320000
# 3       4290000
# 4       3670000

# %%
# Paso 2: enmascaramiento del loyalty_card_number

loyalty_card_number = anonymized["loyalty_card_number"].astype(str).str.zfill(12)

anonymized["loyalty_card_number"] = "********" + loyalty_card_number.str[-4:]

anonymized.head()
# Out:
#    document_id loyalty_card_number  age      city             occupation  \
# 0   1000000001        ********0001   25  Envigado            Comerciante
# 1   1000000002        ********0002   36      Cali  Ingeniero de sistemas
# 2   1000000003        ********0003   38    Bogotá                Docente
# 3   1000000004        ********0004   67    Itagüí                Abogada
# 4   1000000005        ********0005   29    Bogotá            Comerciante
#
#    annual_spend
# 0       2580000
# 1       5400000
# 2       5320000
# 3       4290000
# 4       3670000

# %%
# Paso 3: pseudonimización del documento de identidad

import hashlib
import hmac

secret_key = b"clave-secreta-del-programa"


def pseudonymize(document_id):
    digest = hmac.new(
        secret_key,
        str(document_id).encode("utf-8"),
        hashlib.sha256,
    ).hexdigest()

    return f"CUST-{digest[:12].upper()}"


anonymized["customer_id"] = anonymized["document_id"].apply(pseudonymize)

anonymized = anonymized.drop(columns=["document_id"])

anonymized.head()
# Out:
#   loyalty_card_number  age      city             occupation  annual_spend  \
# 0        ********0001   25  Envigado            Comerciante       2580000
# 1        ********0002   36      Cali  Ingeniero de sistemas       5400000
# 2        ********0003   38    Bogotá                Docente       5320000
# 3        ********0004   67    Itagüí                Abogada       4290000
# 4        ********0005   29    Bogotá            Comerciante       3670000
#
#          customer_id
# 0  CUST-EFF698B261D2
# 1  CUST-E9F4EC0BD860
# 2  CUST-E2C7317583CA
# 3  CUST-6AD4C8020C2B
# 4  CUST-92569771F46C

# %%
# Paso 4: anonimización de la edad

anonymized["age_group"] = pd.cut(
    anonymized["age"],
    bins=[20, 30, 40, 50, 60, 70],
    labels=["20-29", "30-39", "40-49", "50-59", "60-69"],
    right=False,
)

anonymized = anonymized.drop(columns=["age"])

anonymized.head()
# Out:
#   loyalty_card_number      city             occupation  annual_spend  \
# 0        ********0001  Envigado            Comerciante       2580000
# 1        ********0002      Cali  Ingeniero de sistemas       5400000
# 2        ********0003    Bogotá                Docente       5320000
# 3        ********0004    Itagüí                Abogada       4290000
# 4        ********0005    Bogotá            Comerciante       3670000
#
#          customer_id age_group
# 0  CUST-EFF698B261D2     20-29
# 1  CUST-E9F4EC0BD860     30-39
# 2  CUST-E2C7317583CA     30-39
# 3  CUST-6AD4C8020C2B     60-69
# 4  CUST-92569771F46C     20-29

# %%
# Verificación

auxiliary_attack = auxiliary.copy()
auxiliary_attack["age_group"] = pd.cut(
    auxiliary_attack["age"],
    bins=[20, 30, 40, 50, 60, 70],
    labels=["20-29", "30-39", "40-49", "50-59", "60-69"],
    right=False,
)

quasi_identifiers = ["age_group", "city", "occupation"]
candidates = auxiliary_attack.merge(
    anonymized,
    on=quasi_identifiers,
    how="inner",
)

number_of_candidates = (
    candidates.groupby("name").size().reindex(auxiliary["name"], fill_value=0)
)

unique_matches = candidates[candidates["name"].map(number_of_candidates).eq(1)]

print(
    "Perfiles reidentificados de forma única:",
    number_of_candidates.eq(1).sum(),
    "de",
    len(auxiliary),
)

unique_matches.head()
# Out:
# Perfiles reidentificados de forma única: 9 de 20
#                name  age          city   occupation age_group  \
# 0       Laura Gómez   47      Rionegro   Arquitecta     40-49
# 10  Javier Cárdenas   52   Bucaramanga       Médico     50-59
# 11     Diana Correa   45          Cali    Contadora     40-49
# 12     Felipe Vélez   33     Cartagena  Comerciante     30-39
# 23      Isabel Díaz   64  Barranquilla    Enfermera     60-69
#
#    loyalty_card_number  annual_spend        customer_id
# 0         ********0392       5840000  CUST-8ADE272FFEAF
# 10        ********0412       6420000  CUST-391F42D42771
# 11        ********0079       4180000  CUST-CB0B1C18C352
# 12        ********0600       3960000  CUST-3001E46E291C
# 23        ********0146       3520000  CUST-57D10B018171

# %%
# Paso 5: generalización de ciudad a departamento

city_to_department = {
    "Medellín": "Antioquia",
    "Bello": "Antioquia",
    "Envigado": "Antioquia",
    "Itagüí": "Antioquia",
    "Rionegro": "Antioquia",
    "Bogotá": "Bogotá D.C.",
    "Cali": "Valle del Cauca",
    "Barranquilla": "Atlántico",
    "Manizales": "Caldas",
    "Pereira": "Risaralda",
    "Cartagena": "Bolívar",
    "Bucaramanga": "Santander",
}

anonymized["department"] = anonymized["city"].map(city_to_department)

anonymized = anonymized.drop(columns=["city"])

anonymized.head()
# Out:
#   loyalty_card_number             occupation  annual_spend        customer_id  \
# 0        ********0001            Comerciante       2580000  CUST-EFF698B261D2
# 1        ********0002  Ingeniero de sistemas       5400000  CUST-E9F4EC0BD860
# 2        ********0003                Docente       5320000  CUST-E2C7317583CA
# 3        ********0004                Abogada       4290000  CUST-6AD4C8020C2B
# 4        ********0005            Comerciante       3670000  CUST-92569771F46C
#
#   age_group       department
# 0     20-29        Antioquia
# 1     30-39  Valle del Cauca
# 2     30-39      Bogotá D.C.
# 3     60-69        Antioquia
# 4     20-29      Bogotá D.C.

# %%
# Verificación

auxiliary_attack = auxiliary.copy()

auxiliary_attack["age_group"] = pd.cut(
    auxiliary_attack["age"],
    bins=[20, 30, 40, 50, 60, 70],
    labels=["20-29", "30-39", "40-49", "50-59", "60-69"],
    right=False,
)

auxiliary_attack["department"] = auxiliary_attack["city"].map(city_to_department)

quasi_identifiers = ["age_group", "department", "occupation"]

candidates = auxiliary_attack.merge(
    anonymized,
    on=quasi_identifiers,
    how="inner",
)

number_of_candidates = (
    candidates.groupby("name").size().reindex(auxiliary["name"], fill_value=0)
)

unique_matches = candidates[candidates["name"].map(number_of_candidates).eq(1)]

print(
    "Perfiles reidentificados de forma única:",
    number_of_candidates.eq(1).sum(),
    "de",
    len(auxiliary),
)

unique_matches.head()
# Out:
# Perfiles reidentificados de forma única: 7 de 20
#                name  age          city   occupation age_group  \
# 20  Javier Cárdenas   52   Bucaramanga       Médico     50-59
# 21     Diana Correa   45          Cali    Contadora     40-49
# 22     Felipe Vélez   33     Cartagena  Comerciante     30-39
# 44      Isabel Díaz   64  Barranquilla    Enfermera     60-69
# 66    Lucía Londoño   58       Pereira      Docente     50-59
#
#          department loyalty_card_number  annual_spend        customer_id
# 20        Santander        ********0412       6420000  CUST-391F42D42771
# 21  Valle del Cauca        ********0079       4180000  CUST-CB0B1C18C352
# 22          Bolívar        ********0600       3960000  CUST-3001E46E291C
# 44        Atlántico        ********0146       3520000  CUST-57D10B018171
# 66        Risaralda        ********0355       3090000  CUST-8BB7CBF5F7B5

# %%
# Paso 6: generalización de departamento a región

department_to_region = {
    "Antioquia": "Andina",
    "Bogotá D.C.": "Andina",
    "Caldas": "Andina",
    "Risaralda": "Andina",
    "Santander": "Andina",
    "Atlántico": "Caribe",
    "Bolívar": "Caribe",
    "Valle del Cauca": "Pacífica",
}

anonymized["region"] = anonymized["department"].map(department_to_region)

anonymized = anonymized.drop(columns=["department"])

anonymized.head()
# Out:
#   loyalty_card_number             occupation  annual_spend        customer_id  \
# 0        ********0001            Comerciante       2580000  CUST-EFF698B261D2
# 1        ********0002  Ingeniero de sistemas       5400000  CUST-E9F4EC0BD860
# 2        ********0003                Docente       5320000  CUST-E2C7317583CA
# 3        ********0004                Abogada       4290000  CUST-6AD4C8020C2B
# 4        ********0005            Comerciante       3670000  CUST-92569771F46C
#
#   age_group    region
# 0     20-29    Andina
# 1     30-39  Pacífica
# 2     30-39    Andina
# 3     60-69    Andina
# 4     20-29    Andina

# %%
# Verificación

auxiliary_attack = auxiliary.copy()

auxiliary_attack["age_group"] = pd.cut(
    auxiliary_attack["age"],
    bins=[20, 30, 40, 50, 60, 70],
    labels=["20-29", "30-39", "40-49", "50-59", "60-69"],
    right=False,
)

auxiliary_attack["department"] = auxiliary_attack["city"].map(city_to_department)

auxiliary_attack["region"] = auxiliary_attack["department"].map(department_to_region)

quasi_identifiers = ["age_group", "region", "occupation"]

candidates = auxiliary_attack.merge(
    anonymized,
    on=quasi_identifiers,
    how="inner",
)

number_of_candidates = (
    candidates.groupby("name").size().reindex(auxiliary["name"], fill_value=0)
)

unique_matches = candidates[candidates["name"].map(number_of_candidates).eq(1)]

print(
    "Perfiles reidentificados de forma única:",
    number_of_candidates.eq(1).sum(),
    "de",
    len(auxiliary),
)

unique_matches.head()
# Out:
# Perfiles reidentificados de forma única: 2 de 20
#                    name  age  city occupation age_group       department  \
# 45         Diana Correa   45  Cali  Contadora     40-49  Valle del Cauca
# 126  Alejandro Martínez   41  Cali     Médico     40-49  Valle del Cauca
#
#        region loyalty_card_number  annual_spend        customer_id
# 45   Pacífica        ********0079       4180000  CUST-CB0B1C18C352
# 126  Pacífica        ********0427       5970000  CUST-935387D17037

# %%
# Paso 7: generalización de ocupación

occupation_to_group = {
    "Administradora": "Servicios profesionales",
    "Abogada": "Servicios profesionales",
    "Analista financiera": "Servicios profesionales",
    "Contadora": "Servicios profesionales",
    "Arquitecta": "Tecnología y diseño",
    "Diseñadora gráfica": "Tecnología y diseño",
    "Ingeniero de sistemas": "Tecnología y diseño",
    "Médico": "Salud y educación",
    "Enfermera": "Salud y educación",
    "Docente": "Salud y educación",
    "Comerciante": "Comercio y oficios",
    "Técnico electricista": "Comercio y oficios",
}

anonymized["occupation_group"] = anonymized["occupation"].map(occupation_to_group)

anonymized = anonymized.drop(columns=["occupation"])

anonymized.head()
# Out:
#   loyalty_card_number  annual_spend        customer_id age_group    region  \
# 0        ********0001       2580000  CUST-EFF698B261D2     20-29    Andina
# 1        ********0002       5400000  CUST-E9F4EC0BD860     30-39  Pacífica
# 2        ********0003       5320000  CUST-E2C7317583CA     30-39    Andina
# 3        ********0004       4290000  CUST-6AD4C8020C2B     60-69    Andina
# 4        ********0005       3670000  CUST-92569771F46C     20-29    Andina
#
#           occupation_group
# 0       Comercio y oficios
# 1      Tecnología y diseño
# 2        Salud y educación
# 3  Servicios profesionales
# 4       Comercio y oficios

# %%
# Verificación

# %%
# Paso 8: se almacena el archivo

anonymized.to_csv("../submission/anonymized.csv", index=False)

# %%
# Paso 9: evaluación de la utilidad analítica conservada

utility_comparison = pd.DataFrame(
    {
        "dimension": ["Edad", "Ubicación", "Ocupación"],
        "detalle_original": [
            raw["age"].nunique(),
            raw["city"].nunique(),
            raw["occupation"].nunique(),
        ],
        "detalle_anonimizado": [
            anonymized["age_group"].nunique(),
            anonymized["region"].nunique(),
            anonymized["occupation_group"].nunique(),
        ],
    }
)

utility_comparison
# Out:
#    dimension  detalle_original  detalle_anonimizado
# 0       Edad                48                    5
# 1  Ubicación                12                    3
# 2  Ocupación                12                    4
